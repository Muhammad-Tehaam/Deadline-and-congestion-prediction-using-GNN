# %%
                            #########################################################################################################
                            #                                                                                                       #
                            #                                             (MS THESIS)                                               #
                            #     " Multi-Objective Optimization for Deadline-Constrained Data Transfers Between Data Centers "     #
                            #                                                                                                       #
                            #                                     Author: Muhammad Tehaam                                           #
                            #                                                                                                       #
                            #                                     Supervised By: Dr Kashif Munir                                    #
                            #                                                                                                       #
                            #########################################################################################################

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""

                FOR CONNECTING THE LOCAL RUNTIME FOR TRAINING!

pip install jupyter_http_over_ws
jupyter serverextension enable --py jupyter_http_over_ws
jupyter notebook --NotebookApp.allow_origin='https://colab.research.google.com' --port=8888 --NotebookApp.port_retries=2


"""
# Out:
# "\n\n                FOR CONNECTING THE LOCAL RUNTIME FOR TRAINING!\n\npip install jupyter_http_over_ws\njupyter serverextension enable --py jupyter_http_over_ws\njupyter notebook --NotebookApp.allow_origin='https://colab.research.google.com' --port=8888 --NotebookApp.port_retries=2\n\n\n"

# %%
""" DATASET USED FOR THIS PROJECT!  (GERMAN BACKBONE TOPOLOGY)

Dataset = "http://knowledgedefinednetworking.org/data/datasets_v1/gbnbw.tar.gz"

"""
# Out:
# ' DATASET USED FOR THIS PROJECT!  (GERMAN BACKBONE TOPOLOGY)\n\nDataset = "http://knowledgedefinednetworking.org/data/datasets_v1/gbnbw.tar.gz"\n\n'

# %%
"""      ALL DATA IS AVAILBALE ON THE DRIVE!

                              """
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
"""      GENERATE TOPOLOGY

                              """
import networkx as nx
import matplotlib.pyplot as plt
nodes = 17
links = [2, 8, 19, 20, 21, 34, 35, 38, 52, 55, 60, 69, 70, 71, 76, 77, 78, 91, 93, 107, 109, 125, 127, 129, 136, 140, 141, 143, 156, 157, 163, 165, 174, 177, 179, 181, 182, 197, 200, 213, 214, 218, 220, 232, 235, 250, 251, 253, 269, 271, 284, 287]
def draw_topology(nodes, links):
    G = nx.DiGraph()
    for node in range(nodes):
        G.add_node(node)
    for link in links:
        src, dst = link // nodes, link % nodes
        G.add_edge(src, dst, link=link)
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, node_size=700, node_color="skyblue")
    nx.draw_networkx_labels(G, pos, font_size=8, font_color="black", font_weight="bold")
    nx.draw_networkx_edges(G, pos, edge_color="gray", width=0.5, arrowsize=10)
    nx.draw_networkx_edges(G, pos, edge_color="gray", width=0.5, arrowsize=10)
    edge_labels = {(i, j): str(data['link']) for i, j, data in G.edges(data=True)}
    print(edge_labels)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')
    plt.title("Network Topology")
    plt.show()
draw_topology(nodes, links)
# Out:
# {(0, 2): '2', (0, 8): '8', (1, 2): '19', (1, 3): '20', (1, 4): '21', (2, 0): '34', (2, 1): '35', (2, 4): '38', (3, 1): '52', (3, 4): '55', (3, 9): '60', (4, 1): '69', (4, 2): '70', (4, 3): '71', (4, 8): '76', (4, 9): '77', (4, 10): '78', (5, 6): '91', (5, 8): '93', (6, 5): '107', (6, 7): '109', (7, 6): '125', (7, 8): '127', (7, 10): '129', (8, 0): '136', (8, 4): '140', (8, 5): '141', (8, 7): '143', (9, 3): '156', (9, 4): '157', (9, 10): '163', (9, 12): '165', (10, 4): '174', (10, 7): '177', (10, 9): '179', (10, 11): '181', (10, 12): '182', (11, 10): '197', (11, 13): '200', (12, 9): '213', (12, 10): '214', (12, 14): '218', (12, 16): '220', (13, 11): '232', (13, 14): '235', (14, 12): '250', (14, 13): '251', (14, 15): '253', (15, 14): '269', (15, 16): '271', (16, 12): '284', (16, 15): '287'}

# %%
import os
os.chdir("/content/drive/MyDrive/Experimental/code")
# !ls

# %%
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# Ground Truth Updated!
# ...

# %%
# !python dataset_generation.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 19.630169423783844 35.47222204388213 12.188813584770408 0.027928
# 6.717570381501655 33.19885398251687 29.896729040146013 0.029057
# 43.21992808329006 33.18896710597437 22.570645285791365 0.073046
# 26.736887439073097 37.500693935839045 20.077878364797435 0.05648
# 12.22994358974228 30.298578672235823 17.769830621043653 0.203536
# 11.406406187224693 32.08762327200654 15.971985536425594 0.055281
# 4.588640336592849 32.55952073688787 16.826762715127508 0.147352
# 1.8447902822777063 33.37227732655352 29.299768744805643 0.17562
# 12.19830862575487 31.173803335469895 10.396476460735126 0.096589
# 7.708944249689619 32.34204326481506 26.05809067312166 0.265372
# 26.768054362864614 33.31822755518656 22.410239968475473 0.052686
# 1.0075960645528363 30.380602236706657 19.62321826611273 0.244773
# 16.97839563975101 32.54893411059033 14.64234925018593 0.1068
# 27.420324762110603 37.325095114035676 20.311029592136364 0.057324
# ...

# %%
# !wget -O  https://bnn.upc.edu/download/dataset-v6-traffic-models/
# Out:
# wget: missing URL
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.

# %%
# !pip install tensorflow
# Out:
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/93/21/9b035a4f823d6aee2917c75415be9a95861ff3d73a0a65e48edbf210cec1/tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.15.0 from https://files.pythonhosted.org/packages/4c/48/1a5a15517f18eaa4ff8d598b1c000300b20c1bb0e624539d702117a0c369/tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Obtaining dependency information for flatbuffers>=23.5.26 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
# ...

# %%
# !nvidia-smi
# Out:
# Fri Dec 22 07:16:57 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
os.chdir("/content/drive/MyDrive/Experimental/code")
# !python main.py
"""
* NSFNet topology: https://knowledgedefinednetworking.org/data/nsfnet.zip
  (This dataset was randomly partitioned to obtain the training and evaluation datasets)
* GEANT2 topology: https://knowledgedefinednetworking.org/data/geant2.zip
* GBN topology: https://knowledgedefinednetworking.org/data/GBN.zip
  (The last two datasets were used only for evaluation)"""
# Out:
# 2023-12-22 11:50:39.482307: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-22 11:50:39.482360: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-22 11:50:39.483519: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-22 11:50:40.513332: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /content/drive/MyDrive/Experimental/code/main.py:48: RunConfig.__init__ (from tensorflow_estimator.python.estimator.run_config) is deprecated and will be removed in a future version.
# ...

# %%
# !python GNN_evaluate.py --graph=/content/drive/MyDrive/Experimental/logs/model_log/graph.pbtxt --log_dir=/content/drive/MyDrive/Experimental/logs/model_log
# Out:
# 2023-12-22 08:34:26.912337: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-22 08:34:26.912532: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-22 08:34:26.914314: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-22 08:34:26.924678: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !tensorboard --logdir=/content/drive/MyDrive/Experimental/logs/model_log --port 6006 --host localhost
# Out:
# 2023-12-01 14:05:07.655177: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.12.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tempfile
import os
import configparser
from read_dataset import input_fn,return_corresponding_data
from GNN_Model import model_fn
import random
import csv

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.INFO)
#Loading Dataset
new_features = pd.read_csv("dataset.csv")
X = intial_features = new_features.iloc[:, [0, 1, 2, 7, 8,9, 10]].values # generating feature matrix for Model_2
print(X)
print(len(X))
intial_features = new_features.iloc[:, [0, 1, 2, 7, 8, 10]].values # generating feature matrix for Model_2
list_of_lists = [sub_array.tolist() for sub_array in intial_features]
# Out:
# [[7.23622276e+00 1.20213794e+01 5.49761035e+02 ... 3.22172697e+01
#   2.93198000e-01 1.95508001e+01]
#  [3.62062090e+01 1.27443789e+01 2.30591687e+02 ... 3.10401220e+01
#   1.65840000e-01 4.91164279e+01]
#  [3.85447931e+01 9.42396719e+00 2.70909109e+02 ... 3.52610598e+01
#   4.66186000e-01 4.84349462e+01]
#  ...
#  [7.11623298e-01 2.28806340e+01 5.17960786e+02 ... 3.05474112e+01
#   1.98202000e-01 2.37904593e+01]
#  [2.82475058e+00 1.95400958e+01 9.91339369e+02 ... 3.82123239e+01
#   6.34640000e-02 2.24283104e+01]
#  [4.62327162e+00 7.47137569e+00 7.05286788e+02 ... 3.67431127e+01
#   1.01888000e-01 1.21965353e+01]]
# 54400

# %%
"""
        ONLY USE IT FOR INFERENCING TO GET DATA FROM GNN FOR CONNECTED MODEL!

                          """

x = np.array([])  # Define X as an empty numpy array
def multi_modeling_train(test_dir, model_dir, config):
    """Trains double modeling by taking output of GNN and map it to the next model!"""

    estimator = tf.estimator.Estimator(
        model_fn=model_fn,
        model_dir=model_dir,
        params=config
    )

    gnn_output_model1 = estimator.predict(input_fn=lambda: input_fn(test_dir, repeat=False, shuffle=False))
    for data,feature in zip(gnn_output_model1,list_of_lists):
      for input_for_model2 in data.values():
        feature.append(input_for_model2)
        print(feature)

# %%
"""
        ONLY USE IT FOR INFERENCING TO GET DATA FROM GNN FOR CONNECTED MODEL!

                          """
if __name__ == '__main__':
    config = configparser.ConfigParser()
    config._interpolation = configparser.ExtendedInterpolation()
    config.read('../code/config.ini')

    mre = multi_modeling_train(config['DIRECTORIES']['test'],
                        config['DIRECTORIES']['logs'], # Loading trained Weights for model_1
                           config._sections)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '../logs/model_log', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# ...

# %%
"""
        ONLY USE IT FOR INFERENCING TO GET DATA FROM GNN FOR CONNECTED MODEL!

                          """
# X = np.array(list_of_lists)
# print(X)
# # data = X

# # csv_file_path = 'dataset_for_transfer_learning.csv'
# # np.savetxt(csv_file_path, data, delimiter=',', fmt='%f')

# # print(f'Data has been written to {csv_file_path}')
# str(X)
# print(type(X))
# Out:
# '\n        ONLY USE IT FOR INFERENCING TO GET DATA FROM GNN FOR CONNECTED MODEL!\n\n                          '

# %%
# Generating Dependant Variable for Deadline Detection
Y = new_features.iloc[:,-1].values
print(Y)
print(len(Y))
# Out:
# [1 0 0 ... 1 1 1]
# 54400

# %%
# splitting dataset into train and test for second model (To detect Deadline!)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
""" Deep Neural Network for Deadline Predictions
            """
import tensorflow as tf
from tensorflow.keras import layers, regularizers
model_2 = tf.keras.models.Sequential([
    layers.Dense(32, activation='relu', input_shape=(7,)),
    layers.BatchNormalization(),
    layers.Dense(50, activation='relu'),
    layers.Dense(50, activation='relu',kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dense(50, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(50, activation='relu'),
    layers.Dense(50, activation='relu',kernel_regularizer=regularizers.l2(1e-6)),
    layers.Dropout(0.4),
    layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(1e-7)),
    layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(1e-7)),
    layers.Dense(32, activation='sigmoid'),# kernel_regularizer=regularizers.l2(1e-5)),
    layers.Dense(1, activation='tanh')
])

# %%
from matplotlib import pyplot as plt
model_2.compile(tf.keras.optimizers.Adam(learning_rate=0.00001),loss="binary_crossentropy",metrics=['accuracy'])
# model_2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# history = model_2.fit(X_train,Y_train,batch_size=20,epochs=2)#,validation_split = 0.1)
history = model_2.fit(X_train, Y_train, epochs=100, batch_size=20, validation_split=0.1,)# callbacks=[tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
model_2.save("model.keras")
model_2.evaluate(X_test,Y_test)
# Out:
# Epoch 1/100
# 1714/1714 [==============================] - 15s 7ms/step - loss: 1.0896 - accuracy: 0.3988 - val_loss: 0.7780 - val_accuracy: 0.4196
# Epoch 2/100
# 1714/1714 [==============================] - 12s 7ms/step - loss: 0.6563 - accuracy: 0.6282 - val_loss: 0.5756 - val_accuracy: 0.7140
# Epoch 3/100
# 1714/1714 [==============================] - 12s 7ms/step - loss: 0.5504 - accuracy: 0.7248 - val_loss: 0.4646 - val_accuracy: 0.8246
# Epoch 4/100
# 1714/1714 [==============================] - 11s 6ms/step - loss: 0.4610 - accuracy: 0.7810 - val_loss: 0.3695 - val_accuracy: 0.8700
# Epoch 5/100
# 1714/1714 [==============================] - 12s 7ms/step - loss: 0.3831 - accuracy: 0.8294 - val_loss: 0.2865 - val_accuracy: 0.9094
# Epoch 6/100
# 1714/1714 [==============================] - 12s 7ms/step - loss: 0.3147 - accuracy: 0.8693 - val_loss: 0.2182 - val_accuracy: 0.9333
# Epoch 7/100
# ...

# %%
loaded_model = tf.keras.saving.load_model("model.keras")
# Final Deadline Prediction
#1. Source,DST (0,1) Path [0,2,1] ACTUAL LABEL: TRUE
print("Deadline will be Met?",loaded_model.predict(sc.transform([[7.236222,12.0213793753397,549.761034887343,0.548033,32.2172696563275,0.293198,19.5508001312568]]))>0.5)
#2. Source,DST (0,2) Path [0,2]   ACTUAL LABEL: FALSE
print("Deadline will be Met?",loaded_model.predict(sc.transform([[36.2062089730074,12.7443789349656,230.591686556114,0.494247,31.0401219557128,16.584,49.116427907973]]))>0.5)
#3. Source,DST (0,15) Path [0, 8, 7, 10, 12, 14, 15]    ACTUAL LABEL: TRUE
print("Deadline will be Met?",loaded_model.predict(sc.transform([[1.93855239302816,9.93565834877262,480.69903470531,1.73428,37.4769072448405,19.9781,31.8523107418007]]))>0.5)
#4. Source,DST (0,10) Path [0, 8, 7, 10]    ACTUAL LABEL: FALSE
print("Deadline will be Met?",loaded_model.predict(sc.transform([[20.1601975639913,28.4327311975296,550.827300288005,1.26807,36.3215382814725,49.8806,53.580988761521]]))>0.5)
# Out:
# 1/1 [==============================] - 0s 178ms/step
# Deadline will be Met? [[ True]]
# 1/1 [==============================] - 0s 80ms/step
# Deadline will be Met? [[False]]
# 1/1 [==============================] - 0s 62ms/step
# Deadline will be Met? [[ True]]
# 1/1 [==============================] - 0s 31ms/step
# Deadline will be Met? [[False]]

# %%
import pandas as pd
loaded_model = tf.keras.saving.load_model("Final_DNN_Model.keras")
csv_file_path = '/content/drive/MyDrive/Experimental/code/dataset_congestion_predictions.csv'
df = pd.read_csv(csv_file_path, nrows=200)
i = 1
predicted_deadline = []
for index, row in df.iterrows():
    column_names = df.columns
    # for column_name in column_names:
    arrival_t = row["Arrival Time"]
    dur = row["Duration"]
    vol = row["Volume"]
    avg_bw = row["Average Bandwidth"]
    src = row["Source"]
    deadline = row["Deadline"]
    dst = row["Destination"]
    path = row["Path"]
    delay = row["Actual Delay"]
    cT = row["Completion Time"]
    congestion = row["Congestion Probability"]
    print(i,"For Path: ",path," with Source: ",src," and Destination: ",dst)
    print("Deadline will be Met?",loaded_model.predict(sc.transform([[arrival_t,dur,vol,deadline,avg_bw,delay,cT]]))>0.5,"With Congestion Probability: ",congestion)
    # print("Deadline Prob",loaded_model.predict(sc.transform([[arrival_t,dur,vol,deadline,avg_bw,delay,cT]])))
    if loaded_model.predict(sc.transform([[arrival_t,dur,vol,deadline,avg_bw,delay,cT]]))>0.5: predicted_deadline.append(1)
    else: predicted_deadline.append(0)
    print("===========================================================================================================")
    i = i+1

plt.plot(df['Deadline Will be Met'])
plt.plot(predicted_deadline)
plt.title('Deadline Detection')
plt.ylabel('Deadline Meeting')
plt.xlabel('Number of Flows')
plt.legend(['Actual Deadline Will be Met','Detected Deadline will be Met'], loc='upper left')
plt.show()
# Out:
# 1 For Path:  [0, 2, 1]  with Source:  0  and Destination:  1
# 1/1 [==============================] - 0s 51ms/step
# Deadline will be Met? [[False]] With Congestion Probability:  0.50756411
# 1/1 [==============================] - 0s 23ms/step
# ...
# 2 For Path:  [0, 2]  with Source:  0  and Destination:  2
# 1/1 [==============================] - 0s 19ms/step
# Deadline will be Met? [[False]] With Congestion Probability:  0.49873382
# 1/1 [==============================] - 0s 23ms/step
# ...
# 3 For Path:  [0, 2, 1, 3]  with Source:  0  and Destination:  3
# 1/1 [==============================] - 0s 20ms/step
# Deadline will be Met? [[False]] With Congestion Probability:  0.50332304
# 1/1 [==============================] - 0s 18ms/step
# ...
# 4 For Path:  [0, 8, 4]  with Source:  0  and Destination:  4
# 1/1 [==============================] - 0s 20ms/step
# Deadline will be Met? [[False]] With Congestion Probability:  0.49727295
# 1/1 [==============================] - 0s 18ms/step
# ...

# %%
import os
os.chdir("/content/drive/MyDrive/Experimental/code")
# !ls
# Out:
# config.ini			    links_info.csv
# congestion_info.csv		    links_info_updated.csv
# congestion_mapping.py		    logs
# congestion_Model_Results.csv	    main.py
# congestion_predictions.csv	    Modeling_pipeline.py
# datanetAPI.py			    model.keras
# dataset_congestion_predictions.csv  ns-allinone-3.37
# dataset.csv			    ns-allinone-3.37.tar.bz2
# dataset_for_transfer_learning.csv   pipeline.py
# dataset_generation.py		    __pycache__
# experimental_main_congestion.py     read_dataset.py
# Experimental_main.py		    routenet_model.py
# experimental_read_dataset.py	    Second_Experimental_RouteNet.py
# Experimental_RouteNet.py	    WEIGHTS.tf
# ground_truth_dataset.csv

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# !pip install networkx matplotlib

# %%
# !python experimental_main_congestion.py
# Out:
# 2023-11-21 14:37:50.360940: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 14:37:50.361014: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 14:37:50.361066: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 14:37:50.373688: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python congestion_mapping.py
# Out:
# Result Sequence:
# 272
# Data saved to congestion_Model_Results.csv successfully.

# %%
# !python Experimental_main.py
# Out:
# 2023-12-01 15:17:09.799375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /content/drive/MyDrive/Experimental/code/Experimental_main.py:48: RunConfig.__init__ (from tensorflow_estimator.python.estimator.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /content/drive/MyDrive/Experimental/code/Experimental_main.py:48: RunConfig.__init__ (from tensorflow_estimator.python.estimator.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /content/drive/MyDrive/Experimental/code/Experimental_main.py:53: Estimator.__init__ (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# ...

# %%
import pandas as pd
loaded_model = tf.keras.saving.load_model("Final_DNN_Model.keras")
csv_file_path = '/content/drive/MyDrive/Experimental/code/dataset_congestion_predictions.csv'
df = pd.read_csv(csv_file_path, nrows=200)
i = 1
predicted_deadline = []
for index, row in df.iterrows():
    column_names = df.columns
    # for column_name in column_names:
    arrival_t = row["Arrival Time"]
    dur = row["Duration"]
    vol = row["Volume"]
    avg_bw = row["Average Bandwidth"]
    src = row["Source"]
    deadline = row["Deadline"]
    dst = row["Destination"]
    path = row["Path"]
    delay = row["Actual Delay"]
    cT = row["Completion Time"]
    congestion = row["Congestion Probability"]
    print(i,"For Path: ",path," with Source: ",src," and Destination: ",dst)
    print("Deadline will be Met?",loaded_model.predict(sc.transform([[arrival_t,dur,vol,deadline,avg_bw,delay,cT]]))>0.5,"With Congestion Probability: ",congestion)
    #print("Deadline Prob",loaded_model.predict(sc.transform([[arrival_t,dur,vol,deadline,avg_bw,delay,cT]])))
    if loaded_model.predict(sc.transform([[arrival_t,dur,vol,deadline,avg_bw,delay,cT]]))>0.5: predicted_deadline.append(1)
    else: predicted_deadline.append(0)
    print("===========================================================================================================")
    i = i+1

plt.plot(df['Deadline Will be Met'])
plt.plot(predicted_deadline)
plt.title('Deadline Detection')
plt.ylabel('Deadline Meeting')
plt.xlabel('Number of Flows')
plt.legend(['Actual Deadline ','Deadline will be Met'], loc='upper left')
plt.show()
plt.plot(df['Actual Delay'])
plt.plot(random.uniform(0.0,20.0))
plt.title('Congestion Prediction')
plt.ylabel('Congestion')
plt.xlabel('Number of Flows')
plt.legend(['Delay','Congestion'], loc='upper left')
plt.show()
# Out:
# 1 For Path:  [0, 2, 1]  with Source:  0  and Destination:  1
# 1/1 [==============================] - 0s 51ms/step
# Deadline will be Met? [[False]] With Congestion Probability:  0.50756411
# 1/1 [==============================] - 0s 19ms/step
# ...
# 2 For Path:  [0, 2]  with Source:  0  and Destination:  2
# 1/1 [==============================] - 0s 19ms/step
# Deadline will be Met? [[False]] With Congestion Probability:  0.49873382
# 1/1 [==============================] - 0s 20ms/step
# ...
# 3 For Path:  [0, 2, 1, 3]  with Source:  0  and Destination:  3
# 1/1 [==============================] - 0s 18ms/step
# Deadline will be Met? [[False]] With Congestion Probability:  0.50332304
# 1/1 [==============================] - 0s 19ms/step
# ...
# 4 For Path:  [0, 8, 4]  with Source:  0  and Destination:  4
# 1/1 [==============================] - 0s 19ms/step
# Deadline will be Met? [[False]] With Congestion Probability:  0.49727295
# 1/1 [==============================] - 0s 18ms/step
# ...

# %%
""" Custom Dataset Generation Code that uses OMNet++  By BNN Simulators

                                                    """"



import networkx as nx
import random
import os

# Define destination for the generated samples
training_dataset_path = "C:/Users/tehaam/Downloads/Compressed/Experimental-20231212T112103Z-001/Experimental/data/custom dataset/train"
#paths relative to data folder
graphs_path = "graphs"
routings_path = "routings"
tm_path = "tm"
# Path to simulator file
simulation_file = os.path.join(training_dataset_path,"simulation.txt")
# Name of the dataset: Allows you to store several datasets in the same path
# Each dataset will be stored at <training_dataset_path>/results/<name>
dataset_name = "gnn_dataset"


# Create folders
if os.path.isdir(training_dataset_path):
    print ("Destination path already exists. Files within the directory may be overwritten.")
else:
    os.makedirs(os.path.join(training_dataset_path,graphs_path))
    os.mkdir(os.path.join(training_dataset_path,routings_path))
    os.mkdir(os.path.join(training_dataset_path,tm_path))


'''
Generate a graph topology file. The graphs generated have the following characteristics:
- The network is able to process 3 ToS: 0,1,2
- All nodes have buffer sizes of 32000 bits and WFQ scheduling. ToS 0 is assigned to first queue, and ToS 1 and 2 to second queue.
- All links have bandwidths of 100000 bits per second
'''
def generate_topology(net_size, graph_file):
    G = nx.Graph()

    # Set the maximum number of ToS that will use the input traffic of the network
    G.graph["levelsToS"] = 3

    nodes = []
    node_degree = []
    for n in range(net_size):
        node_degree.append(random.choices([2,3,4,5,6],weights=[0.34,0.35,0.2,0.1,0.01])[0])

        nodes.append(n)
        G.add_node(n)
        # Assign to each node the scheduling Policy
        G.nodes[n]["schedulingPolicy"] = "SP"
        # Assign ToS to scheduling queues.
        # In this case we have two queues per port. ToS 0 is assigned to the first queue and ToS 1 and 2 to the second queue
        G.nodes[n]["tosToQoSqueue"] = "0;1,2"
        # Assign weights to each queue
        G.nodes[n]["schedulingWeights"] = "60, 40"
        # Assign the buffer size of all the ports of the node
        G.nodes[n]["bufferSizes"] = 32000

    finish = False
    while True:
        aux_nodes = list(nodes)
        n0 = random.choice(aux_nodes)
        aux_nodes.remove(n0)
        # Remove adjacents nodes (only one link between two nodes)
        for n1 in G[n0]:
            if n1 in aux_nodes:
                aux_nodes.remove(n1)
        if len(aux_nodes) == 0:
            # No more links can be added to this node - can not acomplish node_degree for this node
            nodes.remove(n0)
            if len(nodes) == 1:
                break
            continue
        n1 = random.choice(aux_nodes)
        G.add_edge(n0, n1)
        # Assign the link capacity to the link
        G[n0][n1]["bandwidth"] = 100000

        for n in [n0,n1]:
            node_degree[n] -= 1
            if (node_degree[n] == 0):
                nodes.remove(n)
                if (len(nodes) == 1):
                    finish = True
                    break
        if finish:
            break
    if not nx.is_connected(G):
        G = generate_topology(net_size, graph_file)
        return G

    nx.write_gml(G,graph_file)

    return G



'''
Generate a file with the shortest path routing of the topology G
'''
def generate_routing(G, routing_file):
    with open(routing_file,"w") as r_fd:
        lPaths = nx.shortest_path(G)
        for src in G:
            for dst in G:
                if src == dst:
                    continue
                path =  ','.join(str(x) for x in lPaths[src][dst])
                r_fd.write(path+"\n")






'''
Generate a traffic matrix file. We consider flows between all nodes in the newtork, each with the following characterstics
- The average bandwidth ranges between 10 and max_avg_lbda
- We consider three time distributions (in case of the ON-OFF policy we have on periods of 10 and off periods of 5)
- We consider two packages distributions, chosen at random
- ToS is assigned randomly
'''
import numpy as np
import math
def generate_tm(G, max_avg_lbda, traffic_file):
    poisson = "0"
    cbr = "1"
    on_off = "2,10,5" #time_distribution, avg on_time exp, avg off_time exp
    time_dist = [poisson,cbr,on_off]

    pkt_dist_1 = "0,300,0.5,1700,0.5" #genric pkt size dist, pkt_size 1, prob 1, pkt_size 2, prob 2
    pkt_dist_2 = "0,500,0.6,1000,0.2,1400,0.2" #genric pkt size dist, pkt_size 1, prob 1,
                                               # pkt_size 2, prob 2, pkt_size 3, prob 3
    pkt_size_dist = [pkt_dist_1, pkt_dist_2]
    tos_lst = [0,1,2]

    with open(traffic_file,"w") as tm_fd:
        for src in G:
            for dst in G:
                lambda_value = 0.1  # Parameter for exponential distribution (controls mean arrival time)
                lower_limit_duration = 5  # Lower limit for duration
                upper_limit_duration = 30  # Upper limit for duration
                lower_limit_volume = 100  # Lower limit for volume
                upper_limit_volume = 1000  # Upper limit for volume


                avg_bw = random.randint(10,max_avg_lbda)
                td = random.choice(time_dist)
                sd = random.choice(pkt_size_dist)
                tos = random.choice(tos_lst)

                arrival_time = str(math.ceil(np.random.exponential(scale=1/lambda_value)))
                duration = str(math.ceil(np.random.uniform(lower_limit_duration, upper_limit_duration)))
                volume = str(math.ceil(np.random.uniform(lower_limit_volume, upper_limit_volume)))
                deadline = str(math.ceil(np.random.uniform(20,40)))


                traffic_line = "{},{},{},{},{},{}".format(
                    src,dst,avg_bw,td,sd,tos)
                tm_fd.write(traffic_line+"\n")








"""
We generate the files using the previously defined functions. This code will produce 100 samples where:
- We generate 5 topologies, and then we generate 20 traffic matrices for each
- The topology sizes range from 17 to 50 nodes
- We consider the maximum average bandwidth per flow as 1000
"""
max_avg_lbda = 1000
with open (simulation_file,"w") as fd:
    for net_size in range (17,50):
        #Generate graph
        graph_file = os.path.join(graphs_path,"graph_{}.txt".format(net_size))
        G = generate_topology(net_size, os.path.join(training_dataset_path,graph_file))
        # Generate routing
        routing_file = os.path.join(routings_path,"routing_{}.txt".format(net_size))
        generate_routing(G, os.path.join(training_dataset_path,routing_file))
        # Generate TM:
        for i in range (50):
            tm_file = os.path.join(tm_path,"tm_{}_{}.txt".format(net_size,i))
            generate_tm(G,max_avg_lbda, os.path.join(training_dataset_path,tm_file))
            sim_line = "{},{},{}\n".format(graph_file,routing_file,tm_file)
            # If dataset has been generated in windows, convert paths into linux format
            fd.write(sim_line.replace("\\","/"))





# First we generate the configuration file
import yaml

conf_file = os.path.join(training_dataset_path,"conf.yml")
conf_parameters = {
    "threads": 6,# Number of threads to use
    "dataset_name": dataset_name, # Name of the dataset. It is created in <training_dataset_path>/results/<name>
    "samples_per_file": 1000, # Number of samples per compressed file
    "rm_prev_results": "n", # If 'y' is selected and the results folder already exists, the folder is removed.
}

with open(conf_file, 'w') as fd:
    yaml.dump(conf_parameters, fd)






from getpass import getpass
def docker_cmd(training_dataset_path):
    raw_cmd = f"docker run --rm --mount type=bind,src={os.path.join(os.getcwd(),training_dataset_path)},dst=/data bnnupc/bnnetsimulator"
    terminal_cmd = raw_cmd
    if os.name != 'nt': # Unix, requires sudo
        print("Superuser privileges are required to run docker. Introduce sudo password when prompted")
        terminal_cmd = f"echo {getpass()} | sudo -S " + raw_cmd
        raw_cmd = "sudo " + raw_cmd
    return raw_cmd, terminal_cmd




# Start the docker
raw_cmd, terminal_cmd = docker_cmd(training_dataset_path)
print("The next cell will launch docker from the notebook. Alternatively, run the following command from a terminal:")
print(raw_cmd)

# %%
                            #########################################################################################################
                            #                                                                                                       #
                            #                                     END OF MS THESIS IMPLEMENTATION                                   #
                            #                                                                                                       #
                            #########################################################################################################
